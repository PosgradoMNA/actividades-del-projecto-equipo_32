# %% [markdown]
# # Actividad 1
#
# ## Proyecto final
#
# Equipo_32
#
# Matriculas:
#
# Brenda Rodriguez-A01793984
#
# Cristian Montelongo-A01793580
#
# **1.El nombre que caracteriza el conjunto de datos:**
#
# BM_Captación_202207
#
# (Estas bases vienen de manera mensual, se compilarán todo el 2022)
#
# **2. La organización que lo generó:**
#
# Comisión Nacional Bancaria y de Valores (CNBV)
#
# **3. Incluya un enlace de Internet donde se puedan descargar en línea y enviar como una hoja de cálculo junto con su informe correspondiente:**
#
# https://portafolioinfo.cnbv.gob.mx/PUBLICACIONES/Captacionporlocalidad/Paginas/BM.aspx
#
# **4. Describe el conjunto de datos. ¿Qué datos contiene?:**
#
# Son datos de captación bancaria e información operativa por estado, municipio y localidad.
#
# **5. ¿Cuáles son algunas de las preguntas de investigación que podría responder con estos datos? Enumere al menos OCHO (no responda las preguntas).**
#
# 1.Eficiencia operativa por Banco
#
# 2.Captación per cápita por estados y/o municipios
#
# 3.Análisis de geolocalización (Sucursales Cajeros y TPV)
#
# 4.Optimización de infraestructura por estado de cada institución Financiera
#
# 5.Medición de captación por transaccionalidad
#
# 6.Medición de atracción de nuevas cuentas (Juntando bases de varios meses)
#
# 7.Análisis sobre el comportamiento de saldos promedio ((Juntando bases de varios meses))
#
# 8.Headcount por sucursal
#
# **6.¿Qué actor (empresa, sector de la sociedad, organismo descentralizado, gobierno, etc.) estaría interesado en las preguntas mencionadas que identificó?**
#
# Las entidades financieras de México tanto privadas como gubernamentales.

# %%
import pandas as pd

# %%
pd.read_excel("Base_CNBV.xlsx")
# Out:
#       Base Integral    Unnamed: 1      Unnamed: 2             Unnamed: 3  \
# 0           Reporte     cve_inegi       dl_estado           dl_municipio
# 1             72022  484010010001  AGUASCALIENTES         AGUASCALIENTES
# 2             72022  484010010001  AGUASCALIENTES         AGUASCALIENTES
# 3             72022  484010010001  AGUASCALIENTES         AGUASCALIENTES
# 4             72022  484010010001  AGUASCALIENTES         AGUASCALIENTES
# ...             ...           ...             ...                    ...
# 12842         72022  484320570001       ZACATECAS               TRANCOSO
# 12843         72022  484320580001       ZACATECAS  SANTA MARIA DE LA PAZ
# 12844         72022  484320580001       ZACATECAS  SANTA MARIA DE LA PAZ
# 12845         72022  484320580001       ZACATECAS  SANTA MARIA DE LA PAZ
# 12846         72022  484320580001       ZACATECAS  SANTA MARIA DE LA PAZ
#
#                   Unnamed: 4          Unnamed: 5  \
# ...
